# %% [markdown]
# # Pre configuration

# %%
# Change root folder to "fuzzy-kernels"
print("Configuring root folder...")
import sys
import os
qprc_path = os.path.abspath(os.path.join('..'))
if qprc_path not in sys.path:
    sys.path.append(qprc_path)
sys.path
print("Done!")
# Out:
# Configuring root folder...
# Done!

# %% [markdown]
# # A first (basic) snippet

# %% [markdown]
# Let's start by creating some artificial data, using numpy arrays

# %%
import numpy as np
from numpy.random import uniform

# One hundred elements, between 1 and 10
elements = uniform(1, 10, 100)

print(elements)
# Out:
# [9.05879094 8.97746831 7.21829783 2.57995481 5.67608799 8.55801803
#  8.72399856 9.32215933 7.31885898 2.06924132 4.12744007 3.45842341
#  5.33499342 2.76640463 6.68488675 9.93907101 3.3433566  7.51877239
#  3.42470505 2.81352397 7.94801921 6.73549582 5.14472053 8.3359253
#  8.54412578 3.9371147  7.48358849 8.72423876 9.56468507 9.53647054
#  8.70114762 8.76260449 4.88949167 7.37900627 6.16303595 3.20906326
#  6.33852018 7.41502798 2.0440841  6.84691004 6.25316992 3.86679053
#  3.61357289 1.89776211 3.36793504 1.7681312  6.43911179 5.72008807
#  8.75983791 4.66927059 8.31557259 4.33866047 2.88716342 4.34849525
#  3.94379333 1.05163016 3.96316582 3.67698033 4.12254546 9.29981253
#  6.62589928 4.52754756 5.29813174 7.33008832 6.25389288 9.69423418
#  1.5440777  4.70767322 2.54176114 3.87600456 5.63548412 9.57867013
#  7.67377107 2.57263689 7.06234483 7.70498135 6.34474827 8.55904429
#  2.21355952 7.12043426 2.92066569 5.59856488 7.14888841 3.79800014
#  8.7699706  4.11523951 5.65671497 7.82412365 1.87192828 1.16524193
#  9.06134993 2.031099   1.59024419 7.30153486 9.07668906 7.99275931
#  7.78264954 6.46833437 4.7548109  7.6542802 ]

# %% [markdown]
# Now, let's import a membership function. In this case, we will use a Gaussian membership function, called *gaussmf*, implemented in the library.

# %%
from fs.memberships import gaussmf

mf = gaussmf

print(type(mf))
# Out:
# <class 'function'>

# %% [markdown]
# Observe that *mf* only receives the function signature, because their parameters could be anything. For this function in specific, we are going to need (besides the elements themselves) two more parameters: the __mean__ and the __standard deviation__ of our elements

# %%
mean = np.mean(elements)
std  = np.std(elements)

print("mean = ", mean)
print("std  = ", std)

# Set params as a list
params = [mean, std]
# Out:
# mean =  5.783692932636167
# std  =  2.481757526499395

# %% [markdown]
# With everything set, we can call the main class: the FuzzySet

# %%
from fs.fuzzysets import FuzzySet

fs = FuzzySet(elements, mf=mf, params=params)
fs.show_class()
# Out:
# _elements      =  [9.05879094 8.97746831 7.21829783 2.57995481 5.67608799 8.55801803
#  8.72399856 9.32215933 7.31885898 2.06924132 4.12744007 3.45842341
#  5.33499342 2.76640463 6.68488675 9.93907101 3.3433566  7.51877239
#  3.42470505 2.81352397 7.94801921 6.73549582 5.14472053 8.3359253
#  8.54412578 3.9371147  7.48358849 8.72423876 9.56468507 9.53647054
#  8.70114762 8.76260449 4.88949167 7.37900627 6.16303595 3.20906326
#  6.33852018 7.41502798 2.0440841  6.84691004 6.25316992 3.86679053
#  3.61357289 1.89776211 3.36793504 1.7681312  6.43911179 5.72008807
#  8.75983791 4.66927059 8.31557259 4.33866047 2.88716342 4.34849525
#  3.94379333 1.05163016 3.96316582 3.67698033 4.12254546 9.29981253
#  6.62589928 4.52754756 5.29813174 7.33008832 6.25389288 9.69423418
#  1.5440777  4.70767322 2.54176114 3.87600456 5.63548412 9.57867013
